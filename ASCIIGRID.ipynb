# %% [markdown]
# # The purpose of this notebook is to pull in a NOAA XMRG converted to SHG that is situated over Texas and plot that grid.  This same grid configuration will be used as the temperature grid.  Note the meta data for the grid is presented as well.

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import linecache

# %%
np_array = np.loadtxt(r'C:\Users\m2echjmh\Desktop\Evap_CURG\IDWM\1HR_2013Oct31_0100.tin.asc', skiprows=6)

# %%
np_array
# Out:
# array([[-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        ...,
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.]])

# %%
pd_array = pd.read_table(r'C:\Users\m2echjmh\Desktop\Evap_CURG\IDWM\1HR_2013Oct31_0100.tin.asc', sep='\s+', delimiter=None, header=None, names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=True, skiprows=6, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal='.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=False, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, skip_footer=0, doublequote=True, delim_whitespace=False, as_recarray=False, compact_ints=False, use_unsigned=False, low_memory=True, buffer_lines=None, memory_map=False, float_precision=None)

# %%
pd_array
# Out:
#        0       1       2       3       4       5       6       7       8     \
# 0   -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 1   -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 2   -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 3   -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 4   -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 5   -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 6   -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 7   -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 8   -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 9   -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# 10  -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0 -9999.0
# ...

# %%
line1 = linecache.getline(r'C:\Users\m2echjmh\Desktop\Evap_CURG\IDWM\1HR_2013Oct31_0100.tin.asc', 1)

# %%
line1
# Out:
# 'NCOLS          1043\n'

# %%
x=1
header_list = []
while x < 7:
    header_list.append(linecache.getline(r'C:\Users\m2echjmh\Desktop\Evap_CURG\IDWM\1HR_2013Oct31_0100.tin.asc', x))
    x+=1
header_tuple = tuple(header_list)

# %%
header_list
# Out:
# ['NCOLS          1043\n',
#  'NROWS          825\n',
#  'XLLCORNER      -796.5\n',
#  'YLLCORNER      75.5\n',
#  'CELLSIZE       1.0\n',
#  'NODATA_VALUE   -9999.0\n']

# %%
header_tuple
# Out:
# ('NCOLS          1043\n',
#  'NROWS          825\n',
#  'XLLCORNER      -796.5\n',
#  'YLLCORNER      75.5\n',
#  'CELLSIZE       1.0\n',
#  'NODATA_VALUE   -9999.0\n')

# %%
#Here's what you have:
data_array = np.array(np_array)

# %%
#Mask every position where there is a 0:
masked_data = np.ma.masked_equal(np_array, -9999)

# %%
#Plot the matrix:
fig = plt.figure()
ax = fig.gca()
colmap = plt.get_cmap('gist_ncar') 
ax.matshow(masked_data, cmap=colmap) #_r => reverse the standard color map
plt.tight_layout()
#plt.savefig("rainfall_griddata.png", format="png", bbox_inches='tight', transparent=True, dpi=300)
plt.show()

# %% [markdown]
# for better plotting go here: http://matplotlib.org/basemap/users/examples.html

# %%
header = "NCOLS     %s\n" % np_array.shape[1]
header += "NROWS    %s\n" % np_array.shape[0]
header += "XLLCORNER -796.5\n"
header += "YLLCORNER 75.5\n"
header += "CELLSIZE 1.0\n"
header += "NODATA_value -9999"

np.savetxt(r'C:\Users\m2echjmh\Desktop\Evap_CURG\IDWM\test.asc', np_array, \
header=header, fmt="%1.8f")

# %%
x=1
header_list = []
while x < 15:
    header_list.append(linecache.getline(r'C:\Users\m2echjmh\Desktop\Evap_CURG\IDWM\1HR_2013Oct31_0100.tin.prj', x))
    x+=1
header_tuple = tuple(header_list)

# %%
print header_tuple
# Out:
# ('Projection    ALBERS\n', 'Datum         NAD83\n', 'Spheroid      GRS80\n', 'Units         0.0005\n', 'Zunits        NO\n', 'Xshift        0.0\n', 'Yshift        0.0\n', 'Parameters    \n', '  29 30  0.0 /* 1st standard parallel\n', '  45 30  0.0 /* 2nd standard parallel\n', ' -96  0  0.0 /* central meridian\n', "  23  0  0.0 /* latitude of projection's origin\n", '0.0 /* false easting (meters)\n', '0.0 /* false northing (meters)\n')

# %% [markdown]
# http://desktop.arcgis.com/en/arcmap/latest/map/projections/projection-parameters.htm
